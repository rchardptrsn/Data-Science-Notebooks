# %% [markdown]
# # K-Means Clustering
#
# ### Unsupervised learning algorithm that will attempt to group similar clusters together in your data
# ### Typical clustering problems:
# - Similar documents
# - Customers based on features
# - Market segmentation
# - Similar physical groups

# %%
from IPython.display import Image
Image(filename='kmeansclustering.png')

# %% [markdown]
# ### K Means Algorithm
# - Choose a number of clusters "K"
# - Randomly assign each point to a cluster
# - Until clusters stop changing, repeat the following
#     - For each cluster, compute the cluster centroid by taking the mean vector of points in the cluster
#     - Assign each data point to the cluster for which the centroid is the closest

# %%
Image(filename='kmalgo.png')

# %% [markdown]
# ## There is no easy method for choosing a best K value
# ### Elbow Method:
# - Compute the sum of squared error (SSE) for some values of K (2,4,6,8,etc.)
# - SSE is defined as the sum of the squared distance between each member of the cluster and its centroid
# ### If you plot K against the SSE, you will see that the error decreases as K gets larger.
# - This is because when te number of clusters increases, they should be smaller, so distortion is also smaller
# - Idea of the elbow method is to choose the K at which the SSE decreases abruptly,

# %%
Image(filename='elbowmethod.png')
